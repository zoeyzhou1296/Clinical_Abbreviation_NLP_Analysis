# %%
# # memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

# import psutil
# import humanize
# import os
# import GPUtil as GPU

# GPUs = GPU.getGPUs()
# # XXX: only one GPU on Colab and isn’t guaranteed
# gpu = GPUs[0]
# def printm():
#     process = psutil.Process(os.getpid())
#     print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " |     Proc size: " + humanize.naturalsize(process.memory_info().rss))
#     print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total     {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# printm()

# %%
import pandas as pd
import numpy as np
import random
import codecs
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_validate
from sklearn import naive_bayes, svm
from sklearn.preprocessing import LabelEncoder, FunctionTransformer, StandardScaler
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.svm import SVC
import pickle
import nltk
from nltk.corpus import stopwords


nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # load the data set
# obtained from: https://conservancy.umn.edu/handle/11299/137703

# %%
# read txt file (save the file with utf-8 encoding on visual studio)
column=['short_form','long_form','represent_in_st','pos_start','pos_end','section','compt_st']
f = codecs.open("AnonymizedClinicalAbbreviationsAndAcronymsDataSet_encoded.txt", "r", "utf-8")
dt = pd.read_csv(f, sep='[|]', names=column, keep_default_na=False, na_values=['', 'null'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
dt.head(100)
# Out:
#    short_form  ...                                           compt_st
# 0          AB  ...  _%#NAME#%_ _%#NAME#%_ is a 29-year-old gravida...
# 1          AB  ...  She is now bleeding quite heavily. Ultrasound ...
# 2          AB  ...  ALLERGIES: Heparin and Imitrex. PAST OB HISTOR...
# 3          AB  ...  She had a pelvic ultrasound at Park Nicollet o...
# 4          AB  ...  On _%#MMDD2007#%_, normal anatomy with anterio...
# ..        ...  ...                                                ...
# 95         AB  ...  _%#NAME#%_ _%#NAME#%_ is a 56-year-old female ...
# 96         AB  ...  _%#NAME#%_ _%#NAME#%_ is a 30-year-old teacher...
# 97         AB  ...  She received RhoGAM on _%#MM#%_ _%#DD#%_, 2006...
# 98         AB  ...  CURRENT MEDICATIONS: Prenatal vitamins. ALLERG...
# 99         AB  ...  _%#NAME#%_ _%#NAME#%_ is a 39-year-old female,...
#
# [100 rows x 7 columns]

# %% [markdown]
# ## observe the data

# %%
dt.head(2)
# Out:
#   short_form  ...                                           compt_st
# 0         AB  ...  _%#NAME#%_ _%#NAME#%_ is a 29-year-old gravida...
# 1         AB  ...  She is now bleeding quite heavily. Ultrasound ...
#
# [2 rows x 7 columns]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       37500 non-null  object
#  1   long_form        37500 non-null  object
#  2   represent_in_st  37500 non-null  object
#  3   pos_start        37500 non-null  int64
#  4   pos_end          37500 non-null  int64
#  5   section          36479 non-null  object
#  6   compt_st         37500 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 2.0+ MB

# %%
dt.loc[dt['section'].isnull(), :]
# Out:
#       short_form  ...                                           compt_st
# 0             AB  ...  _%#NAME#%_ _%#NAME#%_ is a 29-year-old gravida...
# 1             AB  ...  She is now bleeding quite heavily. Ultrasound ...
# 9             AB  ...  _%#NAME#%_ _%#NAME#%_ is a 25-year-old female ...
# 22            AB  ...  _%#NAME#%_ _%#NAME#%_ is a 40-year-old female,...
# 23            AB  ...  _%#NAME#%_ _%#NAME#%_ is a 40-year-old female,...
# ...          ...  ...                                                ...
# 37396        VAD  ...  This has led to a sense of needing to vomit an...
# 37438        VAD  ...  He was hospitalized _%#MM#%_ _%#DD#%_ to _%#MM...
# 37443        VAD  ...  His PA pressures have improved significantly f...
# 37444        VAD  ...  His BP is stable and has required NTG for bett...
# 37445        VAD  ...  His BP is stable with a MAP arounf 65-68 mmHg....
#
# [1021 rows x 7 columns]

# %%
# identify if if this data is unbalanced.
dt['long_form'].value_counts()
# Out:
# idiopathic thrombocytopenic purpura                   500
# Narcotics Anonymous                                   474
# (stage) IB                                            472
# over the counter                                      469
# extra strength                                        469
#                                                      ...
# right                                                   1
# pleural effusion                                        1
# methicillin-susceptible Staphylococcus aureus:MSSA      1
# left anterior descending:LAD                            1
# (drug) DC                                               1
# Name: long_form, Length: 351, dtype: int64

# %% [markdown]
# Since the long form is our labels, we first test if there are any inbalance in the data. Since there are many labels only shows once, and we try to avoid the inbalance data, we set the threshold to use the labels are 125. (The most frequency lebels has 500 records, we try to keep (80:20) ratio.

# %%
# build filter for the label:
label_dict = dt['long_form'].value_counts().to_dict()
filtered_label_dict = [key for key, value in label_dict.items() if value > 125]
filtered_label_dict[:5]
# Out:
# ['idiopathic thrombocytopenic purpura',
#  'Narcotics Anonymous',
#  '(stage) IB',
#  'over the counter',
#  'extra strength']

# %%
# keey only labels that have over 125 records 
dt = dt[dt['long_form'].isin(filtered_label_dict)]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32566 entries, 0 to 37499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       32566 non-null  object
#  1   long_form        32566 non-null  object
#  2   represent_in_st  32566 non-null  object
#  3   pos_start        32566 non-null  int64
#  4   pos_end          32566 non-null  int64
#  5   section          31787 non-null  object
#  6   compt_st         32566 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 2.0+ MB

# %%
dt=dt.reset_index(drop=True)
#add id column
dt['id'] = dt.index

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32566 entries, 0 to 32565
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       32566 non-null  object
#  1   long_form        32566 non-null  object
#  2   represent_in_st  32566 non-null  object
#  3   pos_start        32566 non-null  int64
#  4   pos_end          32566 non-null  int64
#  5   section          31787 non-null  object
#  6   compt_st         32566 non-null  object
#  7   id               32566 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 2.0+ MB

# %%
dt.columns
# Out:
# Index(['short_form', 'long_form', 'represent_in_st', 'pos_start', 'pos_end',
#        'section', 'compt_st', 'id'],
#       dtype='object')

# %%
# function Replace represent_in_st to short form to prevent any special character in the short form like M.O.M. to MOM
replace_list = ["compt_st", "represent_in_st", "short_form"]
replace_index_list = [dt.columns.get_loc(c) for c in replace_list if c in dt]
def adv_clean(df, replace_index_list=replace_index_list):
  full_sentenct = df[replace_index_list[0]]
  short_form_represent = df[replace_index_list[1]]
  short_form = df[replace_index_list[2]]
  clean_short_form_sentence = full_sentenct.replace(short_form_represent, short_form)
  return clean_short_form_sentence

# %%
#Text cleaning (keep all special character )
stop = stopwords.words('english')
dt['clean_compt_st']=dt.apply(adv_clean, axis=1)
#delete all nums in string of the dataframe
dt['clean_compt_st'] = dt['clean_compt_st'].str.replace(r'\b[0-9]+\b\s*', ' ')
dt['clean_compt_st'] = dt['clean_compt_st'].str.replace('[^a-zA-Z1-9&]', ' ')
de_identify_list=['mmdd','name','street','city','country','prectinct','address','55400','00000','ddmm2000','mm','dd','2000','ddmm1914','tel','fax','email','ssn','mrn','hpbn','accountn','ln','vn','device']
remove = stop # change the code
pat = r'\b(?:{})\b'.format('|'.join(remove))
dt['clean_compt_st'] = dt['clean_compt_st'].str.replace(pat, '    ')
dt['clean_compt_st'] = dt['clean_compt_st'].str.replace('\s+', ' ', regex=True)
dt['clean_compt_st']=dt['clean_compt_st'].str.lower()
#dt.head()

# %%
# identify 10 words windows around the keyword(short_form)
name_list = ["compt_st", "clean_compt_st", "represent_in_st", "short_form", "pos_start", 'id']
index_list = [dt.columns.get_loc(c) for c in name_list if c in dt]
def extract_windows(data_frame, index_list=index_list):
    sentence = data_frame[index_list[0]]
    clean_sentence = data_frame[index_list[1]]
    raw_keyword = data_frame[index_list[2]]
    keyword = data_frame[index_list[3]]
    pos = data_frame[index_list[4]]
    id_required_revised = data_frame[index_list[5]]
    k = sentence[:int(pos)].split()
    count = sentence[:int(pos)].split().count(raw_keyword) # identify the number of same keywords already appeard before this one
    try:
        if count == 0:
            windows_pos = clean_sentence.split().index(keyword.lower())
        else:
            windows_pos = clean_sentence.replace(keyword.lower(), 'XXXXXX', count).split().index(keyword.lower()) # identify the position of the keywords
    except ValueError:
        print(sentence, pos)
        print(id_required_revised)
        print(clean_sentence, keyword.lower())
        print(count)
        print(clean_sentence.split())
        print(clean_sentence.replace(keyword.lower(), 'XXXXXX', count).split().index(keyword.lower()))
    words = clean_sentence.split()
    res=' '.join(words[max(0,windows_pos-5):min(windows_pos+6,len(words))]) # get the 11 words windows
    return res
  
dt["adv_window"] = dt.apply(extract_windows, axis=1)

# %%
pd.set_option('display.max_colwidth', None)

# %%
dt.head(3)
# Out:
#   short_form  ...                                                                               adv_window
# 0         AB  ...                     the patient known history missed ab she followed another clinic told
# 1         AB  ...  heavily ultrasound morning demonstrated missed ab consistent week pregnancy blood clots
# 2         AB  ...                       term repeat c section spontaneous ab followed suction d&c past gyn
#
# [3 rows x 10 columns]

# %%
pd.reset_option('display.max_colwidth')

# %%
dt['long_form'].value_counts()
# Out:
# idiopathic thrombocytopenic purpura    500
# Narcotics Anonymous                    474
# (stage) IB                             472
# extra strength                         469
# over the counter                       469
#                                       ...
# patent ductus arteriosus               138
# blood group in ABO system              137
# physician assistant certification      137
# lower extremity                        134
# delirium tremens                       129
# Name: long_form, Length: 102, dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32566 entries, 0 to 32565
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       32566 non-null  object
#  1   long_form        32566 non-null  object
#  2   represent_in_st  32566 non-null  object
#  3   pos_start        32566 non-null  int64
#  4   pos_end          32566 non-null  int64
#  5   section          31787 non-null  object
#  6   compt_st         32566 non-null  object
#  7   id               32566 non-null  int64
#  8   clean_compt_st   32566 non-null  object
#  9   adv_window       32566 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### clean categorical feature: Section

# %% [markdown]
# #### transform to numerical label

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32566 entries, 0 to 32565
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       32566 non-null  object
#  1   long_form        32566 non-null  object
#  2   represent_in_st  32566 non-null  object
#  3   pos_start        32566 non-null  int64
#  4   pos_end          32566 non-null  int64
#  5   section          31787 non-null  object
#  6   compt_st         32566 non-null  object
#  7   id               32566 non-null  int64
#  8   clean_compt_st   32566 non-null  object
#  9   adv_window       32566 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 2.5+ MB

# %% [markdown]
# There are around 800 records missing section value

# %%
# fill out missing values for section
dt.loc[dt["section"].isnull(),:][:3]
# Out:
#   short_form  ...                                         adv_window
# 0         AB  ...  the patient known history missed ab she follow...
# 1         AB  ...  heavily ultrasound morning demonstrated missed...
# 8         AB  ...  year old female gravida para ab she previous e...
#
# [3 rows x 10 columns]

# %%
dt['section_test'] = dt['section']

# %%
# since long_form is our prediction, we will use short_form to fill out the blank
mode = dt.groupby('short_form')['section_test'].transform(lambda x: x.mode()[0] if any(x.mode()) else 'ALL_NAN')
dt['section_test'].fillna(mode, inplace=True)

# %%
dt.loc[dt['section_test'] == 'ALL_NAN', :]['short_form'].value_counts()
# Out:
# AC    319
# Name: short_form, dtype: int64

# %% [markdown]
# The short_form 'AC' has no section information available

# %%
# since the 'section' column contain long text as well as special characters, we will transform it to numerical label then
#possible section format 1
section_lst=dt['section_test'].unique().tolist()
dic_section={}
i=0
for word in section_lst:
  dic_section[word]=i
  i=i+1
print(dic_section)

dt['section_id'] = dt['section_test'].replace(dic_section)
#dt.head()
# Out:
# {'HISTORY OF PRESENT ILLNESS': 0, 'PAST OB HISTORY': 1, 'HISTORY OF THE PRESENT ILLNESS': 2, 'PAST OB-GYN HISTORY': 3, 'PATIENT IDENTIFICATION': 4, 'PAST MEDICAL HISTORY': 5, 'HISTORY': 6, 'PLAN': 7, 'HOSPITAL COURSE': 8, 'PREOPERATIVE STATUS AND JUDGMENT': 9, 'PAST SURGICAL HISTORY': 10, 'PREGNANCY HISTORY': 11, 'DATE OF DISCHARGE': 12, 'SUMMARY OF HOSPITAL COURSE': 13, 'PRENATAL LABS': 14, 'ASSESSMENT': 15, 'LABORATORY DATA': 16, 'PREGNANCY COMPLICATIONS': 17, 'GYNECOLOGIC HISTORY': 18, 'REVIEW OF SYSTEMS': 19, 'SURGEON': 20, 'LABORATORY  DATA': 21, 'LABORATORY': 22, 'COMPLICATIONS': 23, 'PAST OBSTETRICAL HISTORY': 24, '1. FEN': 25, 'OB-GYN HISTORY': 26, 'SUMMARY OF ADMISSION': 27, 'PRENATAL LABORATORIES': 28, 'IMPRESSION': 29, 'DOB': 30, 'PRENATAL CARE': 31, 'REASON FOR ADMISSION': 32, 'OB HISTORY': 33, 'PRENATAL LABORATORY': 34, 'PROBLEMS ENCOUNTERED IN THE HOSPITAL': 35, 'DISCHARGE MEDICATIONS': 36, 'GYN HISTORY': 37, 'PAST HISTORY': 38, 'PAST SURGERIES': 39, 'ASSESSMENT/PLAN': 40, 'PHYSICAL EXAMINATION': 41, 'FOLLOW UP': 42, 'ADMISSION DIAGNOSES': 43, 'REASON FOR HOSPITALIZATION': 44, 'PRESENTING INFORMATION': 45, 'MEDICATIONS': 46, 'HISTORY AND HOSPITAL COURSE': 47, 'TELEPHONE INTERACTION': 48, 'CHRONIC DISEASE/MAJOR ILLNESS': 49, 'LABS': 50, 'CHIEF COMPLAINT': 51, 'FOLLOWUP CARE': 52, 'REASON FOR PRESENTATION': 53, 'POSTOPERATIVE COURSE': 54, 'ADMISSION HISTORY AND PHYSICAL': 55, 'PAST GYN HISTORY': 56, 'POSTOPERATIVE DIAGNOSES': 57, 'ADMISSION DIAGNOSIS': 58, 'DISCHARGED 10/19/05': 59, 'LABORATORY STUDIES': 60, 'PRENATAL PROFILE': 61, 'OBSTETRIC HISTORY': 62, 'ADMISSION HISTORY': 63, 'MEDICATION': 64, 'OTHER PROCEDURES': 65, 'NARRATIVE': 66, 'PAST OBSTETRICS HISTORY': 67, 'SOCIAL HISTORY': 68, 'DISCHARGE PLAN': 69, 'DESCRIPTION': 70, 'PAST OBSTETRIC HISTORY': 71, 'ASSESSMENT AND PLAN': 72, 'ALLERGIES': 73, '1. F/E/N': 74, 'BRIEF HISTORY': 75, 'OBSTETRICAL HISTORY': 76, 'SURGERY': 77, 'IMPRESSION/RECOMMENDATIONS': 78, 'INFORMANT SOURCES': 79, 'RECOMMENDATIONS': 80, 'TELEPHONE CONVERSATION': 81, 'SURGERIES': 82, 'PROBLEM': 83, 'PRIOR SURGERY': 84, 'PRIOR SURGICAL HISTORY': 85, 'TBA 7/24/03': 86, 'FAX (952) 985-8299': 87, 'DISCHARGE FOLLOW-UP': 88, 'POSTOP COURSE': 89, 'ANC = 21.2': 90, '* FEN': 91, 'PRIMARY PROCEDURE': 92, 'OB/GYN HISTORY': 93, 'PREOPERATIVE DIAGNOSIS': 94, 'ADMISSION LABORATORY DATA': 95, 'PAST MEDICAL/SURGICAL HISTORY': 96, 'ADMISSION LABS': 97, 'POST-EXTUBATION LABORATORY DATA': 98, 'INITIAL LABORATORY DATA': 99, 'OPERATIVE FINDINGS': 100, 'PROBLEM #2': 101, 'DISCHARGE DIAGNOSES': 102, 'HISTORY AND PHYSICAL': 103, 'COURSE IN HOSPITAL': 104, 'DIAGNOSIS': 105, 'LABORATORY AND IMAGING DATA': 106, 'PROCEDURES PERFORMED DURING THIS HOSPITALIZATION': 107, 'LABS ON ADMISSION': 108, 'ADMITTING HISTORY AND PHYSICAL': 109, 'OPERATIONS/PROCEDURES PERFORMED': 110, 'DISCHARGE APPOINTMENTS': 111, 'LABORATORY RESULTS': 112, 'PROCEDURES PERFORMED DURING HOSPITALIZATION': 113, 'DISCHARGE DIAGNOSIS': 114, 'HISTORY OF PRESENT ILLNESS AND BRIEF HOSPITAL COURSE': 115, 'LABORATORY AND DIAGNOSTICS': 116, 'BRIEF HISTORY OF PRESENT ILLNESS': 117, 'HISTORY OF HOSPITALIZATION': 118, 'DISCHARGE INSTRUCTIONS': 119, 'ADMITTING LABORATORY DATA': 120, 'HISTORY AND PHYSICAL EXAMINATION': 121, 'LABORATORY ASSESSMENT UPON ADMISSION': 122, 'LABORATORY STUDIES ON ADMISSION': 123, 'PROBLEM #4': 124, 'FINAL DIAGNOSIS': 125, 'BRIEF HISTORY OF HOSPITALIZATION': 126, 'COURSE': 127, 'PROBLEM #6': 128, 'SURGICAL HISTORY': 129, 'X-RAY/LAB RESULTS': 130, 'OPERATION PERFORMED': 131, 'HISTORY OF PRESENTING ILLNESS': 132, 'PROCEDURE PERFORMED': 133, 'PHYSICAL EXAMINATION ON ADMISSION': 134, 'LABORATORY DATA/DIAGNOSTICS': 135, 'PROCEDURES PERFORMED': 136, 'DIAGNOSES': 137, 'ADMITTING DIAGNOSIS': 138, 'PERTINENT LABORATORY DATA': 139, 'CHEST X-RAY': 140, 'BRIEF HISTORY AND HOSPITAL COURSE': 141, 'PROBLEM #3': 142, 'PROCEDURES': 143, 'ADMITTING LABS': 144, 'CLOSING': 145, 'OPERATIVE PROCEDURES PERFORMED DURING THIS ADMISSION': 146, 'LABORATORY ON ADMI ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32566 entries, 0 to 32565
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   short_form       32566 non-null  object
#  1   long_form        32566 non-null  object
#  2   represent_in_st  32566 non-null  object
#  3   pos_start        32566 non-null  int64
#  4   pos_end          32566 non-null  int64
#  5   section          31787 non-null  object
#  6   compt_st         32566 non-null  object
#  7   id               32566 non-null  int64
#  8   clean_compt_st   32566 non-null  object
#  9   adv_window       32566 non-null  object
#  10  section_test     32566 non-null  object
#  11  section_id       32566 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 3.0+ MB

# %%
dt['long_form'].value_counts()
# Out:
# idiopathic thrombocytopenic purpura    500
# Narcotics Anonymous                    474
# (stage) IB                             472
# extra strength                         469
# over the counter                       469
#                                       ...
# patent ductus arteriosus               138
# blood group in ABO system              137
# physician assistant certification      137
# lower extremity                        134
# delirium tremens                       129
# Name: long_form, Length: 102, dtype: int64

# %% [markdown]
# ### Train_Test_split (80% and 20%)

# %%
# split the dataset in train and test with test set size of .2
dt_train, dt_test = train_test_split(dt, stratify=dt['long_form'], test_size=.2, random_state = 8)

# %% [markdown]
# # Modeling (Convential Models)

# %% [markdown]
# split the dt_train data to train and validation set with validation size 0.25
#   - train:validation:test = 60:20:20

# %%
train, validation = train_test_split(dt_train, stratify=dt_train['long_form'], test_size=.25, random_state = 8)

# %% [markdown]
# ## Baseline Model

# %% [markdown]
# NLTK NaiveBayesClassifier
# - Bag of words using the 2000 most frequent words in the training data.
# - The abbreviation or acronym

# %%
def get_vocabulary(examples):
    tokens = [word.lower() for example in examples
              for word in nltk.word_tokenize(example[7])]
    vocabulary = nltk.FreqDist(t for t in tokens)
    return list(vocabulary)[:2000] # the 2000 most frequent wors in the training set

# %%
def get_features(train_data, test_data):    
    short_form_vocab = {train_ex[0].lower() for train_ex in train_data}
    vocabulary = get_vocabulary(train_data)

    # (train_features, test_features)
    feature_sets = ([], [])
    for (i, example_set) in enumerate([train_data, test_data]):
        for example in example_set:
            # Add new features in this loop.
            target_sf = example[0]
            sf_feature = get_short_form_feature(target_sf, short_form_vocab)
            document = example[7]
            bow_feature = get_bag_of_words_features(document, vocabulary)
            feat = {**sf_feature, **bow_feature}
            feature_sets[i].append(feat)
    return feature_sets

# %%
def get_short_form_feature(short_form, all_short_forms):
    features = {}
    for sf in all_short_forms:
        features[f"short_form({sf})"] = (sf == short_form.lower())
    features["UNK"] = (short_form.lower() in all_short_forms)
    return features

# %%
def get_bag_of_words_features(document, vocabulary):
    document_words = set(nltk.word_tokenize(document.lower()))
    features = {}
    for word in vocabulary:
        features[f"contains({word})"] = (word in document_words)
    return features

# %%
# get data and label for train set
train_data = train.loc[:, train.columns != 'long_form'].values.tolist()
train_labels = train.loc[:, train.columns == 'long_form'].values.tolist()
train_shuffled = random.sample(list(zip(train_data, train_labels)), k=len(train_data)) # shufffled the list not in place
train_data = [elem[0] for elem in train_shuffled]
train_labels = [elem[1][0] for elem in train_shuffled]


# get data and label for validation set
validation_data = validation.loc[:, validation.columns != 'long_form'].values.tolist()
validation_labels = validation.loc[:, validation.columns == 'long_form'].values.tolist()
validation_shuffled = random.sample(list(zip(validation_data, validation_labels)), k=len(validation_data)) # shufffled the list not in place
validation_data = [elem[0] for elem in validation_shuffled]
validation_labels = [elem[1][0] for elem in validation_shuffled]

# obtain features: 2000 most frequent words and the abbreviation or acronym 
train_feats, validation_feats = get_features(train_data, validation_data)
# train_feats, dt_test_data_feats = get_features(train_data, dt_test_data)
train_examples = zip(train_feats, train_labels)
validation_set = zip(validation_feats, validation_labels)
# dt_test_set = zip(dt_test_data_feats, dt_test_labels)


# use nltk naive bayes classifier
naive_trained_classifier = nltk.NaiveBayesClassifier.train(train_examples)

# prediction
naive_validation = naive_trained_classifier.classify_many(validation_feats)  # fit on the validation set
# naive_predictions = naive_trained_classifier.classify_many(dt_test_data_feats)  # fit on the test set

# %%
print(classification_report(validation_labels, naive_validation, zero_division=0))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.96      0.96      0.96        48
#                 (complement) component 4       0.92      0.98      0.95        46
#                                (drug) AC       0.96      0.75      0.84        32
#                               (stage) IA       0.98      0.98      0.98        55
#                               (stage) IB       1.00      0.98      0.99        94
#                               BK (virus)       0.97      0.97      0.97        69
#          Children's Depression Inventory       1.00      1.00      1.00        54
#              Fairview Southdale Hospital       0.93      0.83      0.87        46
#                          GENERAL ENGLISH       0.78      0.91      0.84        64
#                      Narcotics Anonymous       1.00      0.97      0.98        95
#          Pneumocystis jiroveci pneumonia       0.97      0.98      0.97        59
#                                 T2 (MRI)       0.94      0.98      0.96        45
#                            UNSURED SENSE       0.56      0.45      0.50        44
#                            United States       0.96      0.96      0.96        81
#                                 abortion       0.93      0.99      0.96        69
#                     acetylsalicylic acid       0.93      0.94      0.93        81
#                        acromioclavicular       0.94      1.00      0.97        32
#                         ad lib on demand       0.97      0.91      0.94        81
#                                afternoon       1.00      0.93      0.96        85
#                   against medical advice       0.99      0.97      0.98        89
#                 aortic valve replacement       0.78      0.95      0.86        76
#                         atrioventricular       1.00      0.97      0.99        75
#                  basic metabolic profile       0.95      0.99      0.97        91
#                               below knee       1.00      0.88      0.93        32
#                blood group in ABO system       0.80      0.86      0.83        28
#                           bowel movement       0.99      0.95      0.97        92
#                   bronchoalveolar lavage       1.00      0.99      0.99        92
#                                   cancer       0.97      0.94      0.95        78
#                 carcinoembryonic antigen       0.98      0.97      0.97        89
#            center for diagnostic imaging       0.98      0.93      0.95        45
#                  central venous pressure       0.93      0.94      0.94        87
#                 cerebrovascular accident       0.92      0.89      0.91        55
#                       cervical (level) 3       0.94      0.96      0.95        50
#                       cervical (level) 4       0.94      0.90      0.92        52
#                chorionic villus sampling       0.97      0.92      0.94        92
#                    clear to auscultation       0.79      0.97      0.87        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.88      0.96      0.91        45
#                         delirium tremens       0.96      0.85      0.90        26
#                         dextromethorphan       0.98      0.98      0.98        57
#                        diabetes mellitus       0.95      0.88      0.91        42
#                       diphtheria-tetanus       0.93      0.97      0.95        67
#                           direct current       0.97      0.90      0.93        31
#                              discontinue       0.93      0.96      0.95        56
#                   distal interphalangeal       0.97      0.99      0.98        93
#                           emergency room       0.99      0.94      0.97        89
#                             endotracheal       0.97      0.85      0.91        40
#                           enteric-coated       0.98      0.99      0.98        88
#                     enterostomal therapy       0.95      1.00      0.97        58
#                           extra strength       1.00      0.95      0.97        94
#        fluorescent in situ hybridization       0.98      0.97      0.97        90
#             follicle-stimulating hormone       0.91      0.92      0.92        53
#                         gastrostomy tube       0.91      0.93      0.92        89
#      idiopathic thrombocytopenic purpura       0.99      0.96      0.97       100
#                   in vitro fertilization       0.87      0.89      0.88        61
#                 interventional radiology       0.97      0.95      0.96        79
#                            intraarterial       1.00      0.94      0.97        35
#                            intramuscular       0.97      0.93      0.95        92
#                        intravenous fluid       0.78      0.84      0.81        37
#                       leukocyte esterase       0.85      0.99      0.91        69
#                              long-acting       1.00      0.98      0.99        85
#                          lower extremity       0.83      0.70      0.76        27
#                       magnetic resonance       0.94      0.98      0.96        63
#                      metacarpophalangeal       0.97      0.97      0.97        36
#                     mitral regurgitation       0.91      0.83      0.87        35
#   modified selective severity assessment       0.97      1.00      0.98        83
#                         morphine sulfate       0.83      0.86      0.84        56
#                       multiple sclerosis       0.81      0.69      0.74        42
#                      multiples of median       1.00      0.98      0.99        88
#                        no acute distress       0.91      0.97      0.94        75
#                       nurse practitioner       0.94      0.98      0.96        87
#                           operating room       0.96      0.94      0.95        93
#                               oropharynx       0.92      0.97      0.94        61
#                         over the counter       0.97      0.96      0.96        94
#                 patent ductus arteriosus       0.95      0.78      0.86        27
#                               per rectum       0.96      0.96      0.96        28
#                      peritoneal dialysis       0.96      0.87      0.91        82
#                         physical therapy       0.95      0.96      0.95        91
#        physician assistant certification       0.96      0.96      0.96        27
#              posterior descending artery       0.89      0.97      0.93        72
#                       posterior-anterior       0.98      0.98      0.98        43
#                              pr interval       0.94      1.00      0.97        51
#             premature atrial contraction       0.89      0.93      0.91        55
#                         pulmonary artery       1.00      0.71      0.83        28
#                        pulmonary embolus       0.96      0.96      0.96        82
#                        radiation therapy       0.89      0.88      0.89        67
#                      respiratory therapy       0.85      0.93      0.89        30
#                             right atrium       0.85      0.92      0.88        79
#                          single strength       0.96      0.92      0.94        88
#             slow acting/sustained action       0.96      0.99      0.97        74
#        spontaneous bacterial peritonitis       0.99      0.99      0.99        84
#               superior mesenteric artery       0.96      0.93      0.94        70
#                       thoracic (level) 1       0.95      0.90      0.92        39
#                                thyroxine       0.93      0.95      0.94        85
#                         triiodothyronine       0.96      0.92      0.94        53
#                            tumor stage 1       0.92      0.92      0.92        39
#                            tumor stage 2       0.97      0.97      0.97        33
#                            tumor stage 3       0.82      0.90      0.86        31
#                         venous blood gas       0.93      0.97      0.95        40
#             vertical banded gastroplasty       0.97      0.98      0.98        60
# vincristine adriamycin and dexamethasone       1.00      0.97      0.99        79
#
#                                 accuracy                           0.94      6513
#                                macro avg       0.94      0.93      0.93      6513
#                             weighted avg       0.94      0.94      0.94      6513

# %% [markdown]
# ## TF-IDF Window

# %%
vectorizer_1 = TfidfVectorizer(min_df= 3, sublinear_tf=True, norm='l2', ngram_range=(1, 2))
vectorizer_2 = TfidfVectorizer(min_df= 3, sublinear_tf=True, norm='l2', ngram_range=(1, 3))


#final_features = vectorizer.fit_transform(dt['adv_window']).toarray()
#final_features.shape

# %% [markdown]
# #### Random Forest with n-grams

# %%
# Split our dataset into testing and training set:
X = dt_train['adv_window']
y = dt_train['long_form']
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.25, stratify=y, random_state = 8)

# %% [markdown]
# ##### Random Forest with (1, 2)-grams

# %%
pipeline_rf = Pipeline([('vect', vectorizer_1),
                     ('clf', RandomForestClassifier(random_state=8))])

# Grid Search Parameters for RandomForest
param_grid = {'clf__n_estimators': np.linspace(1, 100, 10, dtype=int),
              'clf__min_samples_split': [3, 10],
              'clf__min_samples_leaf': [2],
              'clf__max_depth': [None],
              'clf__criterion': ['gini'],
              'clf__bootstrap': [False]}

# Training config
kfold = StratifiedKFold(n_splits=5)
scoring = {'Accuracy': 'accuracy', 'F1': 'f1_macro'}
refit = 'F1'

# Perform GridSearch
rf_model_1 = GridSearchCV(pipeline_rf, param_grid=param_grid, cv=kfold, scoring=scoring, 
                         refit=refit, n_jobs=-1, return_train_score=True, verbose=1)
rf_model_1.fit(X_train, y_train)
rf_model_1_best = rf_model_1.best_estimator_
# # fitting our model
yvalidation = np.array(y_validation)
print(classification_report(yvalidation, rf_model_1.predict(X_validation)))
print(rf_model_1.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.40      0.35      0.37        48
#                 (complement) component 4       0.45      0.43      0.44        46
#                                (drug) AC       0.89      1.00      0.94        32
#                               (stage) IA       1.00      0.96      0.98        55
#                               (stage) IB       0.99      1.00      0.99        94
#                               BK (virus)       0.92      1.00      0.96        69
#          Children's Depression Inventory       1.00      0.96      0.98        54
#              Fairview Southdale Hospital       0.98      0.89      0.93        46
#                          GENERAL ENGLISH       0.92      0.88      0.90        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       0.98      1.00      0.99        59
#                                 T2 (MRI)       0.94      0.98      0.96        45
#                            UNSURED SENSE       1.00      0.27      0.43        44
#                            United States       0.99      1.00      0.99        81
#                                 abortion       0.92      1.00      0.96        69
#                     acetylsalicylic acid       0.95      0.95      0.95        81
#                        acromioclavicular       1.00      0.88      0.93        32
#                         ad lib on demand       1.00      1.00      1.00        81
#                                afternoon       0.99      1.00      0.99        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       0.99      1.00      0.99        76
#                         atrioventricular       0.95      0.99      0.97        75
#                  basic metabolic profile       0.99      1.00      0.99        91
#                               below knee       1.00      0.81      0.90        32
#                blood group in ABO system       1.00      0.82      0.90        28
#                           bowel movement       0.98      0.99      0.98        92
#                   bronchoalveolar lavage       0.99      1.00      0.99        92
#                                   cancer       0.97      1.00      0.99        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.92      0.98      0.95        45
#                  central venous pressure       0.97      1.00      0.98        87
#                 cerebrovascular accident       0.96      0.95      0.95        55
#                       cervical (level) 3       0.80      0.78      0.79        50
#                       cervical (level) 4       0.83      0.92      0.87        52
#                chorionic villus sampling       1.00      0.99      0.99        92
#                    clear to auscultation       0.97      0.99      0.98        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.93      0.96      0.95        45
#                         delirium tremens       0.95      0.69      0.80        26
#                         dextromethorphan       0.98      0.95      0.96        57
#                        diabetes mellitus       0.93      0.95      0.94        42
#                       diphtheria-tetanus       0.89      0.99      0.94        67
#                           direct current       1.00      0.84      0.91        31
#                              discontinue       0.92      0.96      0.94        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.98      0.98      0.98        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.93      0.95      0.94        88
#                     enterostomal therapy       1.00      0.97      0.98        58
#                           extra strength       1.00      1.00      1.00        94
#        fluorescent in situ hybridization       0.99      1.00      0.99        90
#             follicle-stimulating hormone       0.93      0.98      0.95        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       1.00      0.99      0.99       100
#                   in vitro fertilization       0.90      0.98      0.94        61
#                 interventional radiology       0.99      0.99      0.99        79
#                            intraarterial       0.92      0.97      0.94        35
#                            intramuscular       0.97      0.99      0.98        92
#                        intravenous fluid       1.00      0.84      0.91        37
#                       leukocyte esterase       0.97      1.00      0.99        69
#                              long-acting       0.98      0.98      0.98        85
#                          lower extremity       1.00      0.85      0.92        27
#                       magnetic resonance       0.95      0.98      0.97        63
#                      metacarpophalangeal       0.89      0.94      0.92        36
#                     mitral regurgitation       1.00      0.91      0.96        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.96      0.93      0.95        56
#                       multiple sclerosis       0.89      0.95      0.92        42
#                      multiples of median       0.99      1.00      0.99        88
#                        no acute distress       0.99      0.99      0.99        75
#                       nurse practitioner       0.99      1.00      0.99        87
#                           operating room       0.93      1.00      0.96        93
#                               oropharynx       0.97      0.98      0.98        61
#                         over the counter       1.00      0.99      0.99        94
#                 patent ductus arteriosus       0.92      0.41      0.56        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      1.00      0.99        82
#                         physical therapy       0.96      1.00      0.98        91
#        physician assistant certification       0.96      1.00      0.98        27
#              posterior descending artery       0.83      0.99      0.90        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      0.92      0.95        51
#             premature atrial contraction       0.98      0.98      0.98        55
#                         pulmonary artery       0.87      0.71      0.78        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.97      0.96      0.96        67
#                      respiratory therapy       0.86      0.80      0.83        30
#                             right atrium       0.92      1.00      0.96        79
#                          single strength       0.99      1.00      0.99        88
#             slow acting/sustained action       0.94      0.99      0.96        74
#        spontaneous bacterial peritonitis       1.00      1.00      1.00        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.72      0.87      0.79        39
#                                thyroxine       0.83      0.93      0.88        85
#                         triiodothyronine       0.84      0.68      0.75        53
#                            tumor stage 1       0.88      0.77      0.82        39
#                            tumor stage 2       1.00      0.85      0.92        33
#                            tumor stage 3       0.83      0.97      0.90        31
#                         venous blood gas       1.00      0.93      0.96        40
#             vertical banded gastroplasty       0.97      1.00      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.95      6513
#                                macro avg       0.95      0.93      0.93      6513
#                             weighted avg       0.95      0.95      0.95      6513
#
# {'clf__bootstrap': False, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 3, 'clf__n_estimators': 56}

# %% [markdown]
# ##### Random Forest with (1, 2, 3)-grams

# %%
pipeline_rf = Pipeline([('vect', vectorizer_2),
                     ('clf', RandomForestClassifier(random_state=8))])

# Grid Search Parameters for RandomForest
param_grid = {'clf__n_estimators': np.linspace(1, 100, 10, dtype=int),
              'clf__min_samples_split': [3, 10],
              'clf__min_samples_leaf': [2],
              'clf__max_depth': [None],
              'clf__criterion': ['gini'],
              'clf__bootstrap': [False]}

# Training config
kfold = StratifiedKFold(n_splits=5)
scoring = {'Accuracy': 'accuracy', 'F1': 'f1_macro'}
refit = 'F1'

# Perform GridSearch
rf_model_2 = GridSearchCV(pipeline_rf, param_grid=param_grid, cv=kfold, scoring=scoring, 
                         refit=refit, n_jobs=-1, return_train_score=True, verbose=1)
rf_model_2.fit(X_train, y_train)
rf_best_2 = rf_model_2.best_estimator_
yvalidation = np.array(y_validation)
print(classification_report(yvalidation, rf_model_2.predict(X_validation)))
print(rf_model_2.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.35      0.35      0.35        48
#                 (complement) component 4       0.38      0.33      0.35        46
#                                (drug) AC       0.91      1.00      0.96        32
#                               (stage) IA       1.00      0.96      0.98        55
#                               (stage) IB       0.99      1.00      0.99        94
#                               BK (virus)       0.90      1.00      0.95        69
#          Children's Depression Inventory       1.00      0.98      0.99        54
#              Fairview Southdale Hospital       0.97      0.74      0.84        46
#                          GENERAL ENGLISH       0.97      0.88      0.92        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       1.00      1.00      1.00        59
#                                 T2 (MRI)       0.88      0.98      0.93        45
#                            UNSURED SENSE       1.00      0.27      0.43        44
#                            United States       0.99      1.00      0.99        81
#                                 abortion       0.95      1.00      0.97        69
#                     acetylsalicylic acid       0.96      0.96      0.96        81
#                        acromioclavicular       1.00      0.91      0.95        32
#                         ad lib on demand       1.00      1.00      1.00        81
#                                afternoon       0.98      1.00      0.99        85
#                   against medical advice       0.99      1.00      0.99        89
#                 aortic valve replacement       0.99      1.00      0.99        76
#                         atrioventricular       0.97      0.99      0.98        75
#                  basic metabolic profile       0.98      1.00      0.99        91
#                               below knee       1.00      0.75      0.86        32
#                blood group in ABO system       1.00      0.89      0.94        28
#                           bowel movement       0.98      0.99      0.98        92
#                   bronchoalveolar lavage       1.00      1.00      1.00        92
#                                   cancer       0.95      1.00      0.97        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.94      0.98      0.96        45
#                  central venous pressure       0.97      1.00      0.98        87
#                 cerebrovascular accident       0.96      0.96      0.96        55
#                       cervical (level) 3       0.75      0.82      0.78        50
#                       cervical (level) 4       0.82      0.88      0.85        52
#                chorionic villus sampling       1.00      0.98      0.99        92
#                    clear to auscultation       0.96      0.99      0.97        79
#                 conjunctivae and sclerae       1.00      1.00      1.00        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.96      0.96      0.96        45
#                         delirium tremens       0.95      0.69      0.80        26
#                         dextromethorphan       0.98      0.96      0.97        57
#                        diabetes mellitus       0.95      0.93      0.94        42
#                       diphtheria-tetanus       0.88      0.99      0.93        67
#                           direct current       1.00      0.77      0.87        31
#                              discontinue       0.89      0.96      0.92        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.95      0.98      0.96        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.94      0.95      0.95        88
#                     enterostomal therapy       1.00      0.97      0.98        58
#                           extra strength       1.00      1.00      1.00        94
#        fluorescent in situ hybridization       0.98      1.00      0.99        90
#             follicle-stimulating hormone       0.86      0.94      0.90        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       1.00      0.99      0.99       100
#                   in vitro fertilization       0.89      0.97      0.93        61
#                 interventional radiology       0.99      1.00      0.99        79
#                            intraarterial       0.92      0.97      0.94        35
#                            intramuscular       0.97      1.00      0.98        92
#                        intravenous fluid       1.00      0.81      0.90        37
#                       leukocyte esterase       0.99      0.99      0.99        69
#                              long-acting       0.98      0.99      0.98        85
#                          lower extremity       1.00      0.93      0.96        27
#                       magnetic resonance       0.94      1.00      0.97        63
#                      metacarpophalangeal       0.89      0.94      0.92        36
#                     mitral regurgitation       1.00      0.91      0.96        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.98      0.93      0.95        56
#                       multiple sclerosis       0.87      0.95      0.91        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.99      0.99      0.99        75
#                       nurse practitioner       0.99      1.00      0.99        87
#                           operating room       0.94      1.00      0.97        93
#                               oropharynx       0.97      0.98      0.98        61
#                         over the counter       1.00      0.99      0.99        94
#                 patent ductus arteriosus       1.00      0.30      0.46        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      1.00      0.99        82
#                         physical therapy       0.94      1.00      0.97        91
#        physician assistant certification       0.96      0.96      0.96        27
#              posterior descending artery       0.79      1.00      0.88        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      0.96      0.97        51
#             premature atrial contraction       0.96      0.98      0.97        55
#                         pulmonary artery       0.87      0.71      0.78        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.94      0.96      0.95        67
#                      respiratory therapy       0.88      0.77      0.82        30
#                             right atrium       0.92      1.00      0.96        79
#                          single strength       0.99      1.00      0.99        88
#             slow acting/sustained action       0.95      0.97      0.96        74
#        spontaneous bacterial peritonitis       1.00      0.98      0.99        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.73      0.85      0.79        39
#                                thyroxine       0.83      0.92      0.87        85
#                         triiodothyronine       0.81      0.79      0.80        53
#                            tumor stage 1       0.96      0.69      0.81        39
#                            tumor stage 2       1.00      0.76      0.86        33
#                            tumor stage 3       0.94      0.97      0.95        31
#                         venous blood gas       1.00      0.95      0.97        40
#             vertical banded gastroplasty       0.97      1.00      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.95      6513
#                                macro avg       0.95      0.93      0.93      6513
#                             weighted avg       0.95      0.95      0.95      6513
#
# {'clf__bootstrap': False, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__n_estimators': 100}

# %% [markdown]
# #### Random Forest with n-grams + section

# %%
X_section = dt_train.loc[:,['adv_window', 'section_id']]
y_section = dt_train['long_form']
X_train_section, X_validation_section, y_train_section, y_validation_section = train_test_split(X_section, y_section, test_size=0.25, stratify=y, random_state = 8)

# %% [markdown]
# ##### Random Foreset with (1, 2)-grams + sectionm

# %%
def get_text_data(x):
    return [record[:] for record in x['adv_window']]


transfomer_category = FunctionTransformer(lambda x: x[['section_id']], validate=False)
transformer_text = FunctionTransformer(get_text_data)

pipeline_rf_with_section = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category)\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_1)
                            ]))\
                        ])), ('clf', RandomForestClassifier())])

# Grid Search Parameters for RandomForest
param_grid = {'clf__n_estimators': np.linspace(1, 100, 10, dtype=int),
              'clf__min_samples_split': [3, 10],
              'clf__min_samples_leaf': [2],
              'clf__max_depth': [None],
              'clf__criterion': ['gini'],
              'clf__bootstrap': [False]}

# Training config
kfold = StratifiedKFold(n_splits=5)
scoring = {'Accuracy': 'accuracy', 'F1': 'f1_macro'}
refit = 'F1'

# Perform GridSearch
rf_model_section_1 = GridSearchCV(pipeline_rf_with_section, param_grid=param_grid, cv=kfold, scoring=scoring, 
                         refit=refit, n_jobs=-1, return_train_score=True, verbose=1)
rf_model_section_1.fit(X_train_section, y_train_section)
rf_best_section_1 = rf_model_section_1.best_estimator_
# # fitting our model
yvalidation_section = np.array(y_validation_section)
print(classification_report(yvalidation_section, rf_model_section_1.predict(X_validation_section)))
print(rf_model_section_1.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.41      0.44      0.42        48
#                 (complement) component 4       0.44      0.35      0.39        46
#                                (drug) AC       0.91      1.00      0.96        32
#                               (stage) IA       1.00      0.98      0.99        55
#                               (stage) IB       0.99      1.00      0.99        94
#                               BK (virus)       0.92      1.00      0.96        69
#          Children's Depression Inventory       1.00      0.98      0.99        54
#              Fairview Southdale Hospital       0.97      0.85      0.91        46
#                          GENERAL ENGLISH       0.95      0.84      0.89        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       1.00      1.00      1.00        59
#                                 T2 (MRI)       0.93      0.93      0.93        45
#                            UNSURED SENSE       1.00      0.27      0.43        44
#                            United States       0.99      1.00      0.99        81
#                                 abortion       0.93      1.00      0.97        69
#                     acetylsalicylic acid       0.96      0.95      0.96        81
#                        acromioclavicular       1.00      0.88      0.93        32
#                         ad lib on demand       0.99      1.00      0.99        81
#                                afternoon       0.99      0.99      0.99        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       0.99      1.00      0.99        76
#                         atrioventricular       0.96      0.99      0.97        75
#                  basic metabolic profile       0.98      1.00      0.99        91
#                               below knee       1.00      0.81      0.90        32
#                blood group in ABO system       1.00      0.86      0.92        28
#                           bowel movement       0.98      0.99      0.98        92
#                   bronchoalveolar lavage       0.99      1.00      0.99        92
#                                   cancer       0.96      0.99      0.97        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.94      0.98      0.96        45
#                  central venous pressure       0.97      1.00      0.98        87
#                 cerebrovascular accident       0.95      0.95      0.95        55
#                       cervical (level) 3       0.78      0.84      0.81        50
#                       cervical (level) 4       0.82      0.90      0.86        52
#                chorionic villus sampling       1.00      0.98      0.99        92
#                    clear to auscultation       0.96      0.99      0.97        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.93      0.96      0.95        45
#                         delirium tremens       0.95      0.73      0.83        26
#                         dextromethorphan       0.98      0.96      0.97        57
#                        diabetes mellitus       0.95      0.93      0.94        42
#                       diphtheria-tetanus       0.90      0.97      0.94        67
#                           direct current       1.00      0.87      0.93        31
#                              discontinue       0.93      0.96      0.95        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.94      0.98      0.96        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.93      0.97      0.95        88
#                     enterostomal therapy       1.00      0.97      0.98        58
#                           extra strength       1.00      1.00      1.00        94
#        fluorescent in situ hybridization       0.98      1.00      0.99        90
#             follicle-stimulating hormone       0.93      0.98      0.95        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       1.00      1.00      1.00       100
#                   in vitro fertilization       0.88      0.98      0.93        61
#                 interventional radiology       0.99      1.00      0.99        79
#                            intraarterial       0.94      0.97      0.96        35
#                            intramuscular       0.97      1.00      0.98        92
#                        intravenous fluid       1.00      0.78      0.88        37
#                       leukocyte esterase       1.00      0.99      0.99        69
#                              long-acting       0.99      0.98      0.98        85
#                          lower extremity       1.00      0.93      0.96        27
#                       magnetic resonance       0.95      1.00      0.98        63
#                      metacarpophalangeal       0.89      0.94      0.92        36
#                     mitral regurgitation       1.00      0.89      0.94        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.96      0.91      0.94        56
#                       multiple sclerosis       0.83      0.93      0.88        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.99      0.99      0.99        75
#                       nurse practitioner       0.97      1.00      0.98        87
#                           operating room       0.92      1.00      0.96        93
#                               oropharynx       0.97      0.98      0.98        61
#                         over the counter       1.00      0.98      0.99        94
#                 patent ductus arteriosus       1.00      0.33      0.50        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      0.99      0.99        82
#                         physical therapy       0.94      1.00      0.97        91
#        physician assistant certification       0.96      1.00      0.98        27
#              posterior descending artery       0.80      1.00      0.89        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.96      0.94      0.95        51
#             premature atrial contraction       0.98      0.98      0.98        55
#                         pulmonary artery       0.87      0.71      0.78        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.94      0.97      0.96        67
#                      respiratory therapy       0.89      0.80      0.84        30
#                             right atrium       0.92      1.00      0.96        79
#                          single strength       0.99      1.00      0.99        88
#             slow acting/sustained action       0.94      0.99      0.96        74
#        spontaneous bacterial peritonitis       1.00      0.99      0.99        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.76      0.90      0.82        39
#                                thyroxine       0.84      0.92      0.88        85
#                         triiodothyronine       0.82      0.68      0.74        53
#                            tumor stage 1       0.97      0.77      0.86        39
#                            tumor stage 2       1.00      0.76      0.86        33
#                            tumor stage 3       0.79      0.97      0.87        31
#                         venous blood gas       1.00      0.95      0.97        40
#             vertical banded gastroplasty       0.97      1.00      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.95      6513
#                                macro avg       0.95      0.93      0.93      6513
#                             weighted avg       0.95      0.95      0.95      6513
#
# {'clf__bootstrap': False, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 3, 'clf__n_estimators': 78}

# %% [markdown]
# ##### Random Foreset with (1, 2, 3)-grams + sectionm

# %%
def get_text_data(x):
    return [record[:] for record in x['adv_window']]


transfomer_category = FunctionTransformer(lambda x: x[['section_id']], validate=False)
transformer_text = FunctionTransformer(get_text_data)

pipeline_rf_with_section = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category)\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_2)
                            ]))\
                        ])), ('clf', RandomForestClassifier())])

# Grid Search Parameters for RandomForest
param_grid = {'clf__n_estimators': np.linspace(1, 100, 10, dtype=int),
              'clf__min_samples_split': [3, 10],
              'clf__min_samples_leaf': [2],
              'clf__max_depth': [None],
              'clf__criterion': ['gini'],
              'clf__bootstrap': [False]}

# Training config
kfold = StratifiedKFold(n_splits=5)
scoring = {'Accuracy': 'accuracy', 'F1': 'f1_macro'}
refit = 'F1'

# Perform GridSearch
rf_model_section_2 = GridSearchCV(pipeline_rf_with_section, param_grid=param_grid, cv=kfold, scoring=scoring, 
                         refit=refit, n_jobs=-1, return_train_score=True, verbose=1)
rf_model_section_2.fit(X_train_section, y_train_section)
rf_best_section_2 = rf_model_section_2.best_estimator_
# # fitting our model
yvalidation_section_2 = np.array(y_validation_section)
print(classification_report(yvalidation_section_2, rf_model_section_2.predict(X_validation_section)))
print(rf_model_section_2.best_params_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.37      0.40      0.38        48
#                 (complement) component 4       0.42      0.33      0.37        46
#                                (drug) AC       0.91      1.00      0.96        32
#                               (stage) IA       1.00      0.96      0.98        55
#                               (stage) IB       0.99      1.00      0.99        94
#                               BK (virus)       0.92      1.00      0.96        69
#          Children's Depression Inventory       1.00      1.00      1.00        54
#              Fairview Southdale Hospital       0.97      0.78      0.87        46
#                          GENERAL ENGLISH       0.95      0.81      0.87        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       0.98      1.00      0.99        59
#                                 T2 (MRI)       0.92      0.98      0.95        45
#                            UNSURED SENSE       1.00      0.27      0.43        44
#                            United States       1.00      1.00      1.00        81
#                                 abortion       0.95      1.00      0.97        69
#                     acetylsalicylic acid       0.96      0.94      0.95        81
#                        acromioclavicular       1.00      0.88      0.93        32
#                         ad lib on demand       1.00      0.99      0.99        81
#                                afternoon       0.98      1.00      0.99        85
#                   against medical advice       0.99      1.00      0.99        89
#                 aortic valve replacement       0.99      1.00      0.99        76
#                         atrioventricular       0.97      0.99      0.98        75
#                  basic metabolic profile       0.98      1.00      0.99        91
#                               below knee       1.00      0.81      0.90        32
#                blood group in ABO system       1.00      0.89      0.94        28
#                           bowel movement       0.98      0.99      0.98        92
#                   bronchoalveolar lavage       0.99      1.00      0.99        92
#                                   cancer       0.99      0.99      0.99        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.96      1.00      0.98        45
#                  central venous pressure       0.97      1.00      0.98        87
#                 cerebrovascular accident       0.93      0.96      0.95        55
#                       cervical (level) 3       0.75      0.84      0.79        50
#                       cervical (level) 4       0.83      0.87      0.85        52
#                chorionic villus sampling       1.00      0.99      0.99        92
#                    clear to auscultation       0.96      0.99      0.97        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       0.99      1.00      0.99        91
#                     costovertebral angle       0.96      0.96      0.96        45
#                         delirium tremens       0.95      0.73      0.83        26
#                         dextromethorphan       0.98      0.91      0.95        57
#                        diabetes mellitus       0.89      0.93      0.91        42
#                       diphtheria-tetanus       0.89      0.99      0.94        67
#                           direct current       1.00      0.84      0.91        31
#                              discontinue       0.92      0.98      0.95        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.97      0.98      0.97        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.91      0.98      0.95        88
#                     enterostomal therapy       1.00      0.97      0.98        58
#                           extra strength       1.00      1.00      1.00        94
#        fluorescent in situ hybridization       0.96      1.00      0.98        90
#             follicle-stimulating hormone       0.87      0.98      0.92        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       1.00      0.99      0.99       100
#                   in vitro fertilization       0.89      0.97      0.93        61
#                 interventional radiology       1.00      1.00      1.00        79
#                            intraarterial       0.92      0.97      0.94        35
#                            intramuscular       0.97      0.99      0.98        92
#                        intravenous fluid       1.00      0.84      0.91        37
#                       leukocyte esterase       0.99      0.99      0.99        69
#                              long-acting       0.99      0.98      0.98        85
#                          lower extremity       1.00      0.93      0.96        27
#                       magnetic resonance       0.90      1.00      0.95        63
#                      metacarpophalangeal       0.89      0.94      0.92        36
#                     mitral regurgitation       1.00      0.80      0.89        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.96      0.93      0.95        56
#                       multiple sclerosis       0.89      0.93      0.91        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.99      0.99      0.99        75
#                       nurse practitioner       0.99      1.00      0.99        87
#                           operating room       0.92      1.00      0.96        93
#                               oropharynx       0.97      0.98      0.98        61
#                         over the counter       1.00      0.99      0.99        94
#                 patent ductus arteriosus       1.00      0.26      0.41        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      1.00      0.99        82
#                         physical therapy       0.95      1.00      0.97        91
#        physician assistant certification       0.96      1.00      0.98        27
#              posterior descending artery       0.78      1.00      0.88        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.96      0.96      0.96        51
#             premature atrial contraction       0.98      0.98      0.98        55
#                         pulmonary artery       0.83      0.71      0.77        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.97      0.96      0.96        67
#                      respiratory therapy       0.89      0.83      0.86        30
#                             right atrium       0.92      1.00      0.96        79
#                          single strength       0.99      1.00      0.99        88
#             slow acting/sustained action       0.95      0.97      0.96        74
#        spontaneous bacterial peritonitis       1.00      0.98      0.99        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.73      0.82      0.77        39
#                                thyroxine       0.81      0.93      0.87        85
#                         triiodothyronine       0.84      0.70      0.76        53
#                            tumor stage 1       0.93      0.72      0.81        39
#                            tumor stage 2       1.00      0.82      0.90        33
#                            tumor stage 3       0.85      0.94      0.89        31
#                         venous blood gas       1.00      0.93      0.96        40
#             vertical banded gastroplasty       0.95      1.00      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.95      6513
#                                macro avg       0.94      0.93      0.93      6513
#                             weighted avg       0.95      0.95      0.95      6513
#
# {'clf__bootstrap': False, 'clf__criterion': 'gini', 'clf__max_depth': None, 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 3, 'clf__n_estimators': 78}

# %% [markdown]
# ### TF-IDF with SVM

# %% [markdown]
# ##### SVM with n-grams

# %%
# Split our dataset into testing and training set:
X = dt_train['adv_window']
y = dt_train['long_form']
X_train, X_validation, y_train, y_validation = train_test_split(X, y, test_size=0.25, stratify=y, random_state = 8)

# %% [markdown]
# ###### SVM with (1, 2)-grams

# %%
pipeline_svm_1 = Pipeline([('vect', vectorizer_1),
                     ('clf', SVC(probability=True, kernel='rbf'))])
# fitting our model
svm_model_1 = pipeline_svm_1.fit(X_train, y_train)
yvalidation_1 = np.array(y_validation)
print(classification_report(yvalidation_1, svm_model_1.predict(X_validation)))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.50      0.56      0.53        48
#                 (complement) component 4       0.50      0.43      0.47        46
#                                (drug) AC       1.00      0.94      0.97        32
#                               (stage) IA       0.98      0.98      0.98        55
#                               (stage) IB       0.99      0.97      0.98        94
#                               BK (virus)       0.95      1.00      0.97        69
#          Children's Depression Inventory       1.00      0.98      0.99        54
#              Fairview Southdale Hospital       0.98      0.96      0.97        46
#                          GENERAL ENGLISH       0.95      0.91      0.93        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       0.98      1.00      0.99        59
#                                 T2 (MRI)       0.98      0.96      0.97        45
#                            UNSURED SENSE       0.56      0.41      0.47        44
#                            United States       1.00      1.00      1.00        81
#                                 abortion       0.99      1.00      0.99        69
#                     acetylsalicylic acid       0.99      0.93      0.96        81
#                        acromioclavicular       1.00      1.00      1.00        32
#                         ad lib on demand       0.99      1.00      0.99        81
#                                afternoon       0.99      0.99      0.99        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       1.00      1.00      1.00        76
#                         atrioventricular       0.99      0.99      0.99        75
#                  basic metabolic profile       0.99      1.00      0.99        91
#                               below knee       1.00      0.84      0.92        32
#                blood group in ABO system       1.00      0.96      0.98        28
#                           bowel movement       1.00      0.99      0.99        92
#                   bronchoalveolar lavage       1.00      1.00      1.00        92
#                                   cancer       1.00      1.00      1.00        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.94      0.98      0.96        45
#                  central venous pressure       0.99      0.99      0.99        87
#                 cerebrovascular accident       0.98      0.96      0.97        55
#                       cervical (level) 3       0.87      0.80      0.83        50
#                       cervical (level) 4       0.85      0.90      0.88        52
#                chorionic villus sampling       1.00      0.99      0.99        92
#                    clear to auscultation       0.97      0.99      0.98        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.96      0.98      0.97        45
#                         delirium tremens       0.95      0.77      0.85        26
#                         dextromethorphan       0.98      0.93      0.95        57
#                        diabetes mellitus       0.91      1.00      0.95        42
#                       diphtheria-tetanus       0.90      0.99      0.94        67
#                           direct current       1.00      0.77      0.87        31
#                              discontinue       0.89      1.00      0.94        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.97      0.98      0.97        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.93      0.99      0.96        88
#                     enterostomal therapy       0.98      0.97      0.97        58
#                           extra strength       1.00      0.99      0.99        94
#        fluorescent in situ hybridization       0.99      1.00      0.99        90
#             follicle-stimulating hormone       1.00      0.98      0.99        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       0.99      0.99      0.99       100
#                   in vitro fertilization       0.94      0.98      0.96        61
#                 interventional radiology       1.00      0.99      0.99        79
#                            intraarterial       1.00      0.94      0.97        35
#                            intramuscular       0.98      0.99      0.98        92
#                        intravenous fluid       1.00      0.92      0.96        37
#                       leukocyte esterase       0.99      1.00      0.99        69
#                              long-acting       1.00      0.96      0.98        85
#                          lower extremity       1.00      0.96      0.98        27
#                       magnetic resonance       0.93      1.00      0.96        63
#                      metacarpophalangeal       0.94      0.94      0.94        36
#                     mitral regurgitation       1.00      0.86      0.92        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.98      0.91      0.94        56
#                       multiple sclerosis       0.84      0.98      0.90        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.97      0.99      0.98        75
#                       nurse practitioner       0.98      1.00      0.99        87
#                           operating room       0.94      1.00      0.97        93
#                               oropharynx       0.98      0.97      0.98        61
#                         over the counter       1.00      0.98      0.99        94
#                 patent ductus arteriosus       0.95      0.70      0.81        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      1.00      0.99        82
#                         physical therapy       0.96      1.00      0.98        91
#        physician assistant certification       0.96      1.00      0.98        27
#              posterior descending artery       0.90      0.99      0.94        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      1.00      0.99        51
#             premature atrial contraction       0.98      0.96      0.97        55
#                         pulmonary artery       0.85      0.79      0.81        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.96      0.96      0.96        67
#                      respiratory therapy       0.90      0.87      0.88        30
#                             right atrium       0.92      0.99      0.95        79
#                          single strength       0.99      0.98      0.98        88
#             slow acting/sustained action       0.97      0.96      0.97        74
#        spontaneous bacterial peritonitis       1.00      1.00      1.00        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.84      0.92      0.88        39
#                                thyroxine       0.96      0.88      0.92        85
#                         triiodothyronine       0.80      0.96      0.87        53
#                            tumor stage 1       0.97      0.92      0.95        39
#                            tumor stage 2       0.97      0.88      0.92        33
#                            tumor stage 3       0.88      0.97      0.92        31
#                         venous blood gas       1.00      0.97      0.99        40
#             vertical banded gastroplasty       0.98      0.98      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.96      6513
#                                macro avg       0.96      0.95      0.95      6513
#                             weighted avg       0.96      0.96      0.96      6513

# %% [markdown]
# ###### SVM with (1, 2, 3)-grams

# %%
pipeline_svm_2 = Pipeline([('vect', vectorizer_2),
                     ('clf', SVC(probability=True, kernel='rbf'))])
# fitting our model
svm_model_2 = pipeline_svm_2.fit(X_train, y_train)
yvalidation_2 = np.array(y_validation)
print(classification_report(yvalidation_2, svm_model_2.predict(X_validation)))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.46      0.54      0.50        48
#                 (complement) component 4       0.46      0.39      0.42        46
#                                (drug) AC       1.00      0.94      0.97        32
#                               (stage) IA       0.98      0.98      0.98        55
#                               (stage) IB       0.99      0.97      0.98        94
#                               BK (virus)       0.95      1.00      0.97        69
#          Children's Depression Inventory       1.00      0.98      0.99        54
#              Fairview Southdale Hospital       0.98      0.96      0.97        46
#                          GENERAL ENGLISH       0.95      0.91      0.93        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       0.98      1.00      0.99        59
#                                 T2 (MRI)       0.96      0.98      0.97        45
#                            UNSURED SENSE       0.55      0.41      0.47        44
#                            United States       1.00      1.00      1.00        81
#                                 abortion       0.97      0.99      0.98        69
#                     acetylsalicylic acid       0.99      0.94      0.96        81
#                        acromioclavicular       1.00      1.00      1.00        32
#                         ad lib on demand       0.99      1.00      0.99        81
#                                afternoon       0.99      0.99      0.99        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       1.00      1.00      1.00        76
#                         atrioventricular       0.99      0.99      0.99        75
#                  basic metabolic profile       0.99      1.00      0.99        91
#                               below knee       1.00      0.84      0.92        32
#                blood group in ABO system       1.00      0.93      0.96        28
#                           bowel movement       1.00      0.99      0.99        92
#                   bronchoalveolar lavage       1.00      1.00      1.00        92
#                                   cancer       0.99      1.00      0.99        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.93      0.96      0.95        45
#                  central venous pressure       0.99      0.98      0.98        87
#                 cerebrovascular accident       0.98      0.96      0.97        55
#                       cervical (level) 3       0.87      0.80      0.83        50
#                       cervical (level) 4       0.85      0.88      0.87        52
#                chorionic villus sampling       1.00      0.99      0.99        92
#                    clear to auscultation       0.97      0.99      0.98        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.96      0.98      0.97        45
#                         delirium tremens       0.95      0.77      0.85        26
#                         dextromethorphan       0.98      0.91      0.95        57
#                        diabetes mellitus       0.89      1.00      0.94        42
#                       diphtheria-tetanus       0.90      0.99      0.94        67
#                           direct current       1.00      0.77      0.87        31
#                              discontinue       0.89      1.00      0.94        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.97      0.98      0.97        89
#                             endotracheal       0.98      1.00      0.99        40
#                           enteric-coated       0.93      0.99      0.96        88
#                     enterostomal therapy       0.98      0.97      0.97        58
#                           extra strength       1.00      0.99      0.99        94
#        fluorescent in situ hybridization       0.99      1.00      0.99        90
#             follicle-stimulating hormone       1.00      0.98      0.99        53
#                         gastrostomy tube       0.99      0.99      0.99        89
#      idiopathic thrombocytopenic purpura       0.99      0.99      0.99       100
#                   in vitro fertilization       0.94      0.98      0.96        61
#                 interventional radiology       1.00      1.00      1.00        79
#                            intraarterial       1.00      0.94      0.97        35
#                            intramuscular       0.98      0.99      0.98        92
#                        intravenous fluid       1.00      0.92      0.96        37
#                       leukocyte esterase       0.99      1.00      0.99        69
#                              long-acting       0.99      0.96      0.98        85
#                          lower extremity       1.00      0.96      0.98        27
#                       magnetic resonance       0.93      1.00      0.96        63
#                      metacarpophalangeal       0.94      0.94      0.94        36
#                     mitral regurgitation       1.00      0.86      0.92        35
#   modified selective severity assessment       1.00      1.00      1.00        83
#                         morphine sulfate       0.98      0.91      0.94        56
#                       multiple sclerosis       0.84      0.98      0.90        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.97      0.99      0.98        75
#                       nurse practitioner       0.99      1.00      0.99        87
#                           operating room       0.94      1.00      0.97        93
#                               oropharynx       0.98      0.97      0.98        61
#                         over the counter       1.00      0.98      0.99        94
#                 patent ductus arteriosus       0.94      0.59      0.73        27
#                               per rectum       1.00      1.00      1.00        28
#                      peritoneal dialysis       0.99      1.00      0.99        82
#                         physical therapy       0.96      1.00      0.98        91
#        physician assistant certification       0.96      1.00      0.98        27
#              posterior descending artery       0.87      0.99      0.92        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      1.00      0.99        51
#             premature atrial contraction       0.98      0.96      0.97        55
#                         pulmonary artery       0.79      0.79      0.79        28
#                        pulmonary embolus       0.98      1.00      0.99        82
#                        radiation therapy       0.96      0.96      0.96        67
#                      respiratory therapy       0.90      0.87      0.88        30
#                             right atrium       0.92      0.97      0.94        79
#                          single strength       0.99      0.98      0.98        88
#             slow acting/sustained action       0.99      0.96      0.97        74
#        spontaneous bacterial peritonitis       1.00      1.00      1.00        84
#               superior mesenteric artery       1.00      1.00      1.00        70
#                       thoracic (level) 1       0.83      0.90      0.86        39
#                                thyroxine       0.94      0.89      0.92        85
#                         triiodothyronine       0.80      0.92      0.86        53
#                            tumor stage 1       0.95      0.92      0.94        39
#                            tumor stage 2       1.00      0.88      0.94        33
#                            tumor stage 3       0.91      0.97      0.94        31
#                         venous blood gas       1.00      0.95      0.97        40
#             vertical banded gastroplasty       0.98      0.98      0.98        60
# vincristine adriamycin and dexamethasone       1.00      1.00      1.00        79
#
#                                 accuracy                           0.96      6513
#                                macro avg       0.95      0.94      0.95      6513
#                             weighted avg       0.96      0.96      0.96      6513

# %% [markdown]
# #### SVM with n-grams + section

# %%
X_section = dt_train.loc[:,['adv_window', 'section_id']]
y_section = dt_train['long_form']
X_train_section, X_validation_section, y_train_section, y_validation_section = train_test_split(X_section, y_section, test_size=0.25, stratify=y, random_state = 8)

# %% [markdown]
# ###### SVM with (1, 2)-grams + section

# %%
def get_text_data(x):
    return [record[:] for record in x['adv_window']]


transfomer_category = FunctionTransformer(lambda x: x[['section_id']], validate=False)
transformer_text = FunctionTransformer(get_text_data)

pipeline_svm_1_section = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category),\
                                ('scaler', StandardScaler(with_mean=False))\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_1)
                            ]))\
                        ])), ('clf', SVC(probability=True, kernel='rbf'))])

svm_model_section_1 = pipeline_svm_1_section.fit(X_train_section, y_train_section)
yvalidation_section = np.array(y_validation_section)
print(classification_report(yvalidation_section, svm_model_section_1.predict(X_validation_section)))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.44      0.60      0.51        48
#                 (complement) component 4       0.43      0.28      0.34        46
#                                (drug) AC       1.00      1.00      1.00        32
#                               (stage) IA       1.00      0.98      0.99        55
#                               (stage) IB       0.99      0.98      0.98        94
#                               BK (virus)       0.92      1.00      0.96        69
#          Children's Depression Inventory       0.81      1.00      0.89        54
#              Fairview Southdale Hospital       1.00      0.78      0.88        46
#                          GENERAL ENGLISH       0.93      0.89      0.91        64
#                      Narcotics Anonymous       0.90      0.97      0.93        95
#          Pneumocystis jiroveci pneumonia       0.98      0.95      0.97        59
#                                 T2 (MRI)       0.98      0.91      0.94        45
#                            UNSURED SENSE       0.40      0.36      0.38        44
#                            United States       1.00      0.94      0.97        81
#                                 abortion       0.97      1.00      0.99        69
#                     acetylsalicylic acid       0.99      0.93      0.96        81
#                        acromioclavicular       1.00      1.00      1.00        32
#                         ad lib on demand       0.99      1.00      0.99        81
#                                afternoon       0.99      0.93      0.96        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       1.00      1.00      1.00        76
#                         atrioventricular       0.99      0.99      0.99        75
#                  basic metabolic profile       0.99      1.00      0.99        91
#                               below knee       1.00      0.81      0.90        32
#                blood group in ABO system       1.00      0.96      0.98        28
#                           bowel movement       1.00      1.00      1.00        92
#                   bronchoalveolar lavage       1.00      1.00      1.00        92
#                                   cancer       1.00      0.97      0.99        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.96      0.96      0.96        45
#                  central venous pressure       0.99      0.99      0.99        87
#                 cerebrovascular accident       0.98      0.89      0.93        55
#                       cervical (level) 3       0.85      0.80      0.82        50
#                       cervical (level) 4       0.89      0.92      0.91        52
#                chorionic villus sampling       0.84      0.95      0.89        92
#                    clear to auscultation       0.97      0.99      0.98        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       1.00      1.00      1.00        91
#                     costovertebral angle       0.96      0.98      0.97        45
#                         delirium tremens       0.95      0.81      0.88        26
#                         dextromethorphan       0.98      0.88      0.93        57
#                        diabetes mellitus       0.86      1.00      0.92        42
#                       diphtheria-tetanus       0.91      0.94      0.93        67
#                           direct current       1.00      0.77      0.87        31
#                              discontinue       0.88      0.95      0.91        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.94      0.96      0.95        89
#                             endotracheal       0.97      0.97      0.97        40
#                           enteric-coated       0.92      0.98      0.95        88
#                     enterostomal therapy       1.00      0.93      0.96        58
#                           extra strength       1.00      0.98      0.99        94
#        fluorescent in situ hybridization       0.80      1.00      0.89        90
#             follicle-stimulating hormone       0.91      0.94      0.93        53
#                         gastrostomy tube       0.97      0.99      0.98        89
#      idiopathic thrombocytopenic purpura       1.00      0.98      0.99       100
#                   in vitro fertilization       0.71      0.97      0.82        61
#                 interventional radiology       1.00      1.00      1.00        79
#                            intraarterial       0.97      0.97      0.97        35
#                            intramuscular       0.98      0.97      0.97        92
#                        intravenous fluid       0.94      0.89      0.92        37
#                       leukocyte esterase       0.96      0.99      0.97        69
#                              long-acting       0.99      0.96      0.98        85
#                          lower extremity       1.00      0.78      0.88        27
#                       magnetic resonance       0.88      0.95      0.92        63
#                      metacarpophalangeal       0.94      0.89      0.91        36
#                     mitral regurgitation       1.00      0.69      0.81        35
#   modified selective severity assessment       1.00      0.99      0.99        83
#                         morphine sulfate       0.96      0.88      0.92        56
#                       multiple sclerosis       0.81      0.83      0.82        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.97      0.99      0.98        75
#                       nurse practitioner       0.98      0.99      0.98        87
#                           operating room       0.91      1.00      0.95        93
#                               oropharynx       0.98      0.93      0.96        61
#                         over the counter       1.00      0.95      0.97        94
#                 patent ductus arteriosus       0.93      0.48      0.63        27
#                               per rectum       1.00      0.93      0.96        28
#                      peritoneal dialysis       0.89      0.96      0.92        82
#                         physical therapy       0.96      1.00      0.98        91
#        physician assistant certification       1.00      1.00      1.00        27
#              posterior descending artery       0.84      0.96      0.90        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      0.94      0.96        51
#             premature atrial contraction       0.98      0.93      0.95        55
#                         pulmonary artery       0.83      0.71      0.77        28
#                        pulmonary embolus       0.98      0.98      0.98        82
#                        radiation therapy       0.95      0.82      0.88        67
#                      respiratory therapy       0.65      0.73      0.69        30
#                             right atrium       0.78      0.97      0.87        79
#                          single strength       1.00      0.98      0.99        88
#             slow acting/sustained action       0.97      0.92      0.94        74
#        spontaneous bacterial peritonitis       1.00      0.94      0.97        84
#               superior mesenteric artery       0.99      0.96      0.97        70
#                       thoracic (level) 1       0.82      0.82      0.82        39
#                                thyroxine       0.96      0.75      0.84        85
#                         triiodothyronine       0.66      0.94      0.78        53
#                            tumor stage 1       0.97      0.74      0.84        39
#                            tumor stage 2       0.93      0.82      0.87        33
#                            tumor stage 3       0.87      0.84      0.85        31
#                         venous blood gas       1.00      0.95      0.97        40
#             vertical banded gastroplasty       0.98      0.98      0.98        60
# vincristine adriamycin and dexamethasone       1.00      0.96      0.98        79
#
#                                 accuracy                           0.94      6513
#                                macro avg       0.93      0.92      0.92      6513
#                             weighted avg       0.94      0.94      0.94      6513

# %% [markdown]
# ###### SVM with (1, 2, 3)-grams + section

# %%
pipeline_svm_2_section = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category),\
                                ('scaler', StandardScaler(with_mean=False))\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_2)
                            ]))\
                        ])), ('clf', SVC(probability=True, kernel='rbf'))])

svm_model_section_2 = pipeline_svm_2_section.fit(X_train_section, y_train_section)
yvalidation_section_2 = np.array(y_validation_section)
print(classification_report(yvalidation_section_2, svm_model_section_2.predict(X_validation_section)))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.44      0.62      0.52        48
#                 (complement) component 4       0.41      0.26      0.32        46
#                                (drug) AC       1.00      1.00      1.00        32
#                               (stage) IA       0.98      1.00      0.99        55
#                               (stage) IB       0.99      0.98      0.98        94
#                               BK (virus)       0.93      1.00      0.97        69
#          Children's Depression Inventory       0.78      1.00      0.88        54
#              Fairview Southdale Hospital       1.00      0.85      0.92        46
#                          GENERAL ENGLISH       0.95      0.89      0.92        64
#                      Narcotics Anonymous       0.84      0.95      0.89        95
#          Pneumocystis jiroveci pneumonia       0.98      0.95      0.97        59
#                                 T2 (MRI)       0.98      0.91      0.94        45
#                            UNSURED SENSE       0.41      0.36      0.39        44
#                            United States       1.00      0.94      0.97        81
#                                 abortion       0.96      1.00      0.98        69
#                     acetylsalicylic acid       0.99      0.94      0.96        81
#                        acromioclavicular       1.00      1.00      1.00        32
#                         ad lib on demand       0.99      1.00      0.99        81
#                                afternoon       0.99      0.93      0.96        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       1.00      1.00      1.00        76
#                         atrioventricular       0.99      0.99      0.99        75
#                  basic metabolic profile       0.99      1.00      0.99        91
#                               below knee       1.00      0.84      0.92        32
#                blood group in ABO system       1.00      0.93      0.96        28
#                           bowel movement       1.00      1.00      1.00        92
#                   bronchoalveolar lavage       1.00      1.00      1.00        92
#                                   cancer       0.99      0.96      0.97        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.96      0.96      0.96        45
#                  central venous pressure       0.99      0.98      0.98        87
#                 cerebrovascular accident       0.98      0.87      0.92        55
#                       cervical (level) 3       0.83      0.80      0.82        50
#                       cervical (level) 4       0.89      0.90      0.90        52
#                chorionic villus sampling       0.80      0.95      0.87        92
#                    clear to auscultation       0.97      0.99      0.98        79
#                 conjunctivae and sclerae       1.00      0.99      0.99        87
#                       controlled release       0.99      1.00      0.99        91
#                     costovertebral angle       0.93      0.96      0.95        45
#                         delirium tremens       0.95      0.81      0.88        26
#                         dextromethorphan       0.98      0.88      0.93        57
#                        diabetes mellitus       0.88      1.00      0.93        42
#                       diphtheria-tetanus       0.91      0.93      0.92        67
#                           direct current       1.00      0.77      0.87        31
#                              discontinue       0.88      0.95      0.91        56
#                   distal interphalangeal       0.98      1.00      0.99        93
#                           emergency room       0.95      0.94      0.95        89
#                             endotracheal       0.97      0.97      0.97        40
#                           enteric-coated       0.92      0.98      0.95        88
#                     enterostomal therapy       1.00      0.93      0.96        58
#                           extra strength       1.00      0.98      0.99        94
#        fluorescent in situ hybridization       0.78      1.00      0.87        90
#             follicle-stimulating hormone       0.96      0.92      0.94        53
#                         gastrostomy tube       0.96      0.98      0.97        89
#      idiopathic thrombocytopenic purpura       1.00      0.99      0.99       100
#                   in vitro fertilization       0.71      0.97      0.82        61
#                 interventional radiology       1.00      1.00      1.00        79
#                            intraarterial       1.00      0.97      0.99        35
#                            intramuscular       0.98      0.98      0.98        92
#                        intravenous fluid       0.94      0.89      0.92        37
#                       leukocyte esterase       0.96      0.99      0.97        69
#                              long-acting       0.99      0.96      0.98        85
#                          lower extremity       1.00      0.78      0.88        27
#                       magnetic resonance       0.88      0.95      0.92        63
#                      metacarpophalangeal       0.94      0.89      0.91        36
#                     mitral regurgitation       1.00      0.66      0.79        35
#   modified selective severity assessment       1.00      0.99      0.99        83
#                         morphine sulfate       0.98      0.86      0.91        56
#                       multiple sclerosis       0.81      0.83      0.82        42
#                      multiples of median       1.00      1.00      1.00        88
#                        no acute distress       0.97      0.99      0.98        75
#                       nurse practitioner       0.98      0.98      0.98        87
#                           operating room       0.95      1.00      0.97        93
#                               oropharynx       0.98      0.93      0.96        61
#                         over the counter       1.00      0.93      0.96        94
#                 patent ductus arteriosus       0.93      0.48      0.63        27
#                               per rectum       1.00      0.93      0.96        28
#                      peritoneal dialysis       0.92      0.96      0.94        82
#                         physical therapy       0.96      1.00      0.98        91
#        physician assistant certification       1.00      1.00      1.00        27
#              posterior descending artery       0.84      0.96      0.90        72
#                       posterior-anterior       1.00      0.95      0.98        43
#                              pr interval       0.98      0.94      0.96        51
#             premature atrial contraction       0.98      0.93      0.95        55
#                         pulmonary artery       0.77      0.71      0.74        28
#                        pulmonary embolus       0.98      0.98      0.98        82
#                        radiation therapy       0.95      0.82      0.88        67
#                      respiratory therapy       0.65      0.73      0.69        30
#                             right atrium       0.75      0.96      0.84        79
#                          single strength       1.00      0.98      0.99        88
#             slow acting/sustained action       0.99      0.92      0.95        74
#        spontaneous bacterial peritonitis       1.00      0.94      0.97        84
#               superior mesenteric artery       1.00      0.96      0.98        70
#                       thoracic (level) 1       0.82      0.79      0.81        39
#                                thyroxine       0.96      0.76      0.85        85
#                         triiodothyronine       0.66      0.91      0.76        53
#                            tumor stage 1       0.94      0.74      0.83        39
#                            tumor stage 2       0.93      0.82      0.87        33
#                            tumor stage 3       0.87      0.84      0.85        31
#                         venous blood gas       1.00      0.95      0.97        40
#             vertical banded gastroplasty       0.98      0.98      0.98        60
# vincristine adriamycin and dexamethasone       1.00      0.96      0.98        79
#
#                                 accuracy                           0.93      6513
#                                macro avg       0.93      0.91      0.92      6513
#                             weighted avg       0.94      0.93      0.93      6513

# %% [markdown]
# ## Cross-validation

# %% [markdown]
# create the cross validation data set

# %%
X_cv = dt_train['adv_window']
X_cv_section = dt_train.loc[:,['adv_window', 'section_id']]
y_cv = dt_train['long_form']

# %%
accuracy = []

# %%
cv = StratifiedKFold(n_splits=5, random_state=123, shuffle=True)
pipeline_rf_1 = Pipeline([('vect', vectorizer_1),
                  ('clf', RandomForestClassifier(n_estimators=56, min_samples_leaf=2, min_samples_split=3))])
accuracy.append(cross_validate(pipeline_rf_1, X_cv, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_rf_2 = Pipeline([('vect', vectorizer_2),
                  ('clf', RandomForestClassifier(n_estimators=100, min_samples_leaf=2, min_samples_split=10))])
accuracy.append(cross_validate(pipeline_rf_2, X_cv, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_rf_with_section_1 = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category)\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_1)
                            ]))\
                        ])), ('clf', RandomForestClassifier(n_estimators=78, min_samples_leaf=2, min_samples_split=3))])
accuracy.append(cross_validate(pipeline_rf_with_section_1, X_cv_section, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_rf_with_section_2 = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category)\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_2)
                            ]))\
                        ])), ('clf', RandomForestClassifier(n_estimators=78, min_samples_leaf=2, min_samples_split=3))])
accuracy.append(cross_validate(pipeline_rf_with_section_2, X_cv_section, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

# %%
pipeline_svm_1 = Pipeline([('vect', vectorizer_1),
                  ('clf', SVC(probability=True, kernel='rbf'))])
accuracy.append(cross_validate(pipeline_svm_1, X_cv, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_svm_2 = Pipeline([('vect', vectorizer_2),
                  ('clf', SVC(probability=True, kernel='rbf'))])
accuracy.append(cross_validate(pipeline_svm_2, X_cv, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_svm_with_section_1 = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category),\
                                ('scaler', StandardScaler(with_mean=False))\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_1)
                            ]))\
                        ])), ('clf', SVC(probability=True, kernel='rbf'))])
accuracy.append(cross_validate(pipeline_svm_with_section_1, X_cv_section, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

pipeline_svm_with_section_2 = Pipeline([
                         ('features', FeatureUnion([\
                            ('numeric_features', Pipeline([\
                                ('selector', transfomer_category),\
                                ('scaler', StandardScaler(with_mean=False))\
                            ])),\
                            ('text_features', Pipeline([\
                                ('selector', transformer_text),\
                                ('vec', vectorizer_2)
                            ]))\
                        ])), ('clf', SVC(probability=True, kernel='rbf'))])
accuracy.append(cross_validate(pipeline_svm_with_section_2, X_cv_section, y_cv, scoring=['accuracy', 'f1_weighted'], cv=cv, n_jobs=-1, return_train_score=True))

# %%
accuracy
# Out:
#                                             fit_time  ...                                  train_f1_weighted
# 0  [7.463834047317505, 7.54076623916626, 7.153670...  ...  [0.9604356711576487, 0.9626830346813915, 0.963...
# 1  [13.108197689056396, 13.029526710510254, 12.77...  ...  [0.9634474837830358, 0.96014285148193, 0.96158...
# 2  [9.863546371459961, 9.880082130432129, 9.60763...  ...  [0.962948653807088, 0.9646345984520984, 0.9620...
# 3  [10.798992156982422, 10.909960985183716, 10.78...  ...  [0.9607025458125964, 0.9603035246565451, 0.961...
# 4  [882.2351791858673, 885.651451587677, 887.3583...  ...  [0.9973596039112126, 0.9974070706062603, 0.996...
# 5  [986.4656262397766, 987.6787304878235, 1008.43...  ...  [0.9973602348264609, 0.9975031685484838, 0.996...
# 6  [807.0318870544434, 806.8023536205292, 787.596...  ...  [0.9889670387521904, 0.9882154402963218, 0.988...
# 7  [888.0014510154724, 886.6452074050903, 876.490...  ...  [0.9880949941907136, 0.9879877430071982, 0.988...
#
# [8 rows x 6 columns]

# %%
df = pd.DataFrame(accuracy)
result_table = pd.DataFrame()
col_names = df_a.columns
for name in col_names:
  result_table[name] = np.mean(df_a[name].tolist(), axis=1)

# %%
result_table
# Out:
#      fit_time  score_time  ...  train_accuracy  train_f1_weighted
# 0    6.742147    0.555332  ...        0.963458           0.961232
# 1   11.984500    0.897091  ...        0.963477           0.961269
# 2    9.048508    0.710682  ...        0.965243           0.963180
# 3   10.013789    0.794977  ...        0.962987           0.960775
# 4  836.192251   37.830103  ...        0.997150           0.997148
# 5  945.550765   41.342226  ...        0.997035           0.997033
# 6  751.663976   38.673800  ...        0.988696           0.988673
# 7  833.815899   40.786686  ...        0.988216           0.988194
#
# [8 rows x 6 columns]

# %% [markdown]
# Based on the runtime, weighted average F1 score, and accuracy, we choose Random Forest with unigrams, bigrams and section information.

# %% [markdown]
# ## Model Performance

# %% [markdown]
# Apply the chosed model fit the training set, and then apply it to the test set.

# %%
X_train = dt_train.loc[:,['adv_window', 'section_id']]
y_train = dt_train['long_form']
X_test = dt_test.loc[:,['adv_window', 'section_id']]
y_test = dt_test['long_form']

# %%
ytest = np.array(y_test)
# classification report(precision, recall, F1-score)
pipeline_rf_with_section_1.fit(X_train, y_train)
ytest = np.array(y_test)
print(classification_report(ytest, pipeline_rf_with_section_1.predict(X_test)))
# Out:
#                                           precision    recall  f1-score   support
#
#                 (complement) component 3       0.40      0.43      0.41        49
#                 (complement) component 4       0.45      0.30      0.36        46
#                                (drug) AC       0.94      1.00      0.97        32
#                               (stage) IA       1.00      1.00      1.00        55
#                               (stage) IB       0.99      1.00      0.99        94
#                               BK (virus)       0.96      0.99      0.97        69
#          Children's Depression Inventory       1.00      0.98      0.99        54
#              Fairview Southdale Hospital       0.98      0.89      0.93        46
#                          GENERAL ENGLISH       0.94      0.72      0.81        64
#                      Narcotics Anonymous       1.00      1.00      1.00        95
#          Pneumocystis jiroveci pneumonia       1.00      0.97      0.98        59
#                                 T2 (MRI)       0.92      1.00      0.96        45
#                            UNSURED SENSE       1.00      0.13      0.24        45
#                            United States       0.99      1.00      0.99        80
#                                 abortion       0.91      1.00      0.95        69
#                     acetylsalicylic acid       0.96      1.00      0.98        81
#                        acromioclavicular       1.00      0.91      0.95        32
#                         ad lib on demand       1.00      1.00      1.00        81
#                                afternoon       1.00      1.00      1.00        85
#                   against medical advice       1.00      1.00      1.00        89
#                 aortic valve replacement       0.99      1.00      0.99        76
#                         atrioventricular       0.93      1.00      0.96        75
#                  basic metabolic profile       0.97      1.00      0.98        91
#                               below knee       0.97      0.90      0.93        31
#                blood group in ABO system       1.00      0.81      0.90        27
#                           bowel movement       0.96      1.00      0.98        92
#                   bronchoalveolar lavage       0.99      1.00      0.99        91
#                                   cancer       0.99      1.00      0.99        78
#                 carcinoembryonic antigen       1.00      1.00      1.00        89
#            center for diagnostic imaging       0.96      1.00      0.98        45
#                  central venous pressure       0.98      1.00      0.99        87
#                 cerebrovascular accident       1.00      0.98      0.99        56
#                       cervical (level) 3       0.70      0.78      0.74        50
#                       cervical (level) 4       0.79      0.88      0.84        52
#                chorionic villus sampling       1.00      1.00      1.00        91
#                    clear to auscultation       0.99      1.00      0.99        79
#                 conjunctivae and sclerae       0.99      1.00      0.99        87
#                       controlled release       0.99      1.00      0.99        91
#                     costovertebral angle       1.00      1.00      1.00        44
#                         delirium tremens       1.00      0.62      0.76        26
#                         dextromethorphan       1.00      0.93      0.96        57
#                        diabetes mellitus       0.91      0.98      0.94        42
#                       diphtheria-tetanus       0.86      1.00      0.92        67
#                           direct current       1.00      0.90      0.95        30
#                              discontinue       0.95      0.98      0.96        56
#                   distal interphalangeal       0.96      1.00      0.98        92
#                           emergency room       0.95      1.00      0.97        90
#                             endotracheal       1.00      0.97      0.99        40
#                           enteric-coated       0.98      0.97      0.97        88
#                     enterostomal therapy       0.98      0.98      0.98        58
#                           extra strength       0.98      0.99      0.98        94
#        fluorescent in situ hybridization       0.93      1.00      0.96        90
#             follicle-stimulating hormone       0.94      0.94      0.94        53
#                         gastrostomy tube       0.99      1.00      0.99        89
#      idiopathic thrombocytopenic purpura       1.00      1.00      1.00       100
#                   in vitro fertilization       0.85      0.97      0.90        62
#                 interventional radiology       0.99      0.99      0.99        79
#                            intraarterial       1.00      0.97      0.99        35
#                            intramuscular       1.00      0.99      0.99        92
#                        intravenous fluid       0.96      0.58      0.72        38
#                       leukocyte esterase       0.96      0.99      0.97        69
#                              long-acting       0.99      1.00      0.99        85
#                          lower extremity       0.91      0.78      0.84        27
#                       magnetic resonance       0.86      1.00      0.93        63
#                      metacarpophalangeal       0.91      0.89      0.90        36
#                     mitral regurgitation       1.00      0.80      0.89        35
#   modified selective severity assessment       0.98      1.00      0.99        84
#                         morphine sulfate       0.96      0.95      0.95        56
#                       multiple sclerosis       0.93      1.00      0.96        41
#                      multiples of median       0.99      1.00      0.99        88
#                        no acute distress       0.99      1.00      0.99        75
#                       nurse practitioner       0.95      1.00      0.97        88
#                           operating room       0.92      1.00      0.96        93
#                               oropharynx       0.98      0.98      0.98        62
#                         over the counter       0.99      1.00      0.99        94
#                 patent ductus arteriosus       0.75      0.11      0.19        28
#                               per rectum       0.93      1.00      0.97        28
#                      peritoneal dialysis       0.98      1.00      0.99        82
#                         physical therapy       0.94      1.00      0.97        91
#        physician assistant certification       1.00      0.89      0.94        27
#              posterior descending artery       0.73      0.99      0.84        72
#                       posterior-anterior       1.00      0.90      0.95        42
#                              pr interval       0.98      0.88      0.93        50
#             premature atrial contraction       0.95      0.98      0.96        55
#                         pulmonary artery       0.87      0.96      0.91        27
#                        pulmonary embolus       0.92      1.00      0.96        82
#                        radiation therapy       0.95      0.94      0.95        67
#                      respiratory therapy       0.96      0.80      0.87        30
#                             right atrium       1.00      0.99      0.99        79
#                          single strength       1.00      1.00      1.00        88
#             slow acting/sustained action       0.93      1.00      0.96        75
#        spontaneous bacterial peritonitis       1.00      1.00      1.00        83
#               superior mesenteric artery       0.99      0.99      0.99        71
#                       thoracic (level) 1       0.82      0.79      0.81        39
#                                thyroxine       0.78      0.79      0.78        85
#                         triiodothyronine       0.62      0.61      0.62        54
#                            tumor stage 1       0.97      0.88      0.92        40
#                            tumor stage 2       0.96      0.79      0.87        33
#                            tumor stage 3       0.88      0.90      0.89        31
#                         venous blood gas       1.00      0.93      0.96        40
#             vertical banded gastroplasty       0.95      0.98      0.97        60
# vincristine adriamycin and dexamethasone       0.99      1.00      0.99        79
#
#                                 accuracy                           0.95      6514
#                                macro avg       0.94      0.92      0.92      6514
#                             weighted avg       0.95      0.95      0.94      6514
